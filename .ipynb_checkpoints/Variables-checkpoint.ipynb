# %% [markdown]
# ### Variables de la base
#
# *Date de la première alerte:* je suppose le moment où est parvenu le premier signalement de l'incendie?
#
# *Origine de l'alerte:* et par quel moyen?
#
# *Moyens de première intervention:* ?
#
# *Précision  des surfaces:* Estimées ou mesurées
#
# *Voie carrosable la plus proche:* je suppose type de celle ci mais quelle correspondance chiffre type?
#
# *Activité ou habitation la plus proche:
#
# *Type de peuplement:*
#
# *Connaissance:* ??
#
# *Source de l'enquête:* service de police et de gendarmerie/sapeur-pompiers/coordinateur...
#
# *Nature:* du feu
#
# *Intervention de l'équipe RCCI:* Recherche des Causes et Circonstances des Incendies
#
# *Hygrométrie:* taux d'humidité dans l'air
#
# *Présence d'un contour valide:*
#
#
# **Surfaces**
#
# _Forêt:_
# Surface touchée par l’incendie située en forêt uniquement. Sont considérés comme étant de la forêt (définition FAO) les milieux naturels boisés qui répondaient avant l’incendie à l’ensemble des critères suivants
#
# *
#
# Taux de couvert arboré (végétaux ligneux pouvant atteindre in situ plus de 5 m de haut à maturité) supérieur à 0* S;
# Surface d’un seul tenant de plus de 0.5 ha minu* m ;
# Largeur supérieure à2* 0 m.
# Les plantations et jeunes peuplements forestiers issus de régénération naturelle ou artificielle, ainsi que les garrigues et maquis sont considérés comme étant de la
#
#
# orêt.
# En revanche,les surfaces boisées ne répondant pas aux critères mentionnés ci-dessus ne sont pas à considérer comme étant de laf
# _orêt.
#
# Autres surface:_  boisées
# Un terrain de type autres terres boisées, est un terrain qui satisfait aux 3 critères
# s* uivants:
#
# Soit un couvert par des arbres compris entre     * 5 et 10 % ;
# Soit un couvert par d'autres végétaux ligneux supérieur o
# * gal à 10 % ;
# Une surface supérieure ou égale à 50 a
# * es (0,5 ha) ;
# Une largeur supérieure ou éga
#     le à 20 mètres.
# Cette définition européenne correspond, pour partie, à la définition utilisée par l'IGN pour la "lande" (Terrain avec un taux de recouvrement de végétaux non cultivé supérieur
#
# _ égal à 10 %).
#
# Surface no:_  boisée naturelle
# Rassemblent les landes herbacées ou très peu arbustives (les landes arbustives sont incluses dans les autres terres boisées), les prairies naturelles et l_es zones humide:_ .
#
# Autres surfaces
# Surface parcourue par le feu dans des milieux autres que les trois catégories ci-dessus. Concerne notamment les surfaces de friches, les talus et les zones végétalisées artificielles (jardins, pelouses, parc urbain).
